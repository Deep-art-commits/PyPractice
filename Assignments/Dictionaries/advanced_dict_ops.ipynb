# %% [markdown]
# ### Assignment 11: Dictionary Filtering
#
# Create a dictionary with the first 10 positive integers as keys and their squares as values. Create a new dictionary containing only the key-value pairs where the key is even. Print the new dictionary.

# %%
f_10_dict={i:i**2 for i in range(1,11) }
new_dict={k:v for k,v in f_10_dict.items() if k%2==0 }
print(f_10_dict)
print(new_dict)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
# {2: 4, 4: 16, 6: 36, 8: 64, 10: 100}

# %% [markdown]
# ### Assignment 12: Dictionary Key and Value Transformation
#
# Create a dictionary with the first 5 positive integers as keys and their squares as values. Create a new dictionary with keys and values swapped. Print the new dictionary.

# %%
f_10_dict={i:i**2 for i in range(1,11) }
new_dict={v:k for k,v in f_10_dict.items()  }
print(f_10_dict)
print(new_dict)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
# {1: 1, 4: 2, 9: 3, 16: 4, 25: 5, 36: 6, 49: 7, 64: 8, 81: 9, 100: 10}

# %%
from collections import defaultdict

default_dict = defaultdict(list)
default_dict['a'].append(1)
default_dict['a'].append(2)
default_dict['b'].append(3)
print(default_dict)
# Out:
# defaultdict(<class 'list'>, {'a': [1, 2], 'b': [3]})

# %% [markdown]
# ### Assignment 14: Counting with Dictionaries
#
# Write a function that takes a string and returns a dictionary with the count of each character in the string. Print the dictionary.

# %%
def count_words_dict(inp_string):
    count_dict={}
    for ch in inp_string.strip():
        count_dict[ch]=count_dict.get(ch,0)+1
    return count_dict

print(count_words_dict("Hello") )
# Out:
# {'H': 1, 'e': 1, 'l': 2, 'o': 1}

# %%
import json

book = {
    'title': 'To Kill a Mockingbird',
    'author': 'Harper Lee',
    'year': 1960,
    'genre': 'Fiction'
}
book_json = json.dumps(book)
print(book_json)
# Out:
# {"title": "To Kill a Mockingbird", "author": "Harper Lee", "year": 1960, "genre": "Fiction"}

# %%
|
